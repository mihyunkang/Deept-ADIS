# %%
import os
def createfolder(folder):
    try:
        if not os.path.exists(folder):
            os.makedirs(folder)
    except OSError:
        print('Error: creating directory' + folder)

# %%
# !pip install face_recognition
# Out:
# ^C

# %% [markdown]
# # NEW face extraction

# %%
import PIL
from PIL import Image
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

def load_image_file(file, mode='RGB'):
    im = PIL.Image.open(file)
    if mode:
        im = im.convert(mode)
    if torch.cuda.device_count()>1:
        im = nn.DataParallel(np.array(im))
    return im.to(device)
# Out:
# cuda

# %%
import cv2
import numpy as np
import face_recognition
import re
import os
from PIL import Image

# 한 디렉토리 안의 모든 비디오 파일들에 대해.
def directory_video(directory):
    #frame_save = videoname+'_frame'
    #print(frame_save)
    
    video_files = os.listdir(directory)
    for file in video_files:
        extract_frame(directory+'\\'+file)

# %%
# 비디오에 대해 프레임 추출
#frame_save_path = videoname+'_frame'

#total = 0

def extract_frame(filename):
    #path 
    print(filename)
    #print("number of video :{}".format(total))
    folder_path = 'D:\\dataset\\real'
    file_name = filename.split('\\')[2]
    video = cv2.VideoCapture(filename)
    count = 0
    num=-1

    #create save folders
    #createfolder(folder_path)
    
    videoframe = video.get(cv2.CAP_PROP_POS_FRAMES)
    videocount = video.get(cv2.CAP_PROP_FRAME_COUNT)

    while video.isOpened():
        #ret 은 프레임이 존재하지 않을때 T/F 반환
        #frame 은 프레임 반환
        num+=1
        '''
        if(videoframe == videocount):
            video.open(filename)
        '''
        ret, frame = video.read()
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    

        if ret == False:
            print("Frame doesn't Exist")
            break
        if num % 100 == 0:
            #total += 1
            if(videoframe == videocount):
                video.open(filename)

            try:

                #face_location 은 얼굴 위치(행렬에서)
                face_location = face_recognition.face_locations(frame) #cnn 모델 사용 X. 원할시, model='cnn' 입력(GPU 없는 기기에서는 실행되지 않음)
                top, right, bottom, left = face_location[0]
                print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

                #face_location 찾아서 파일로 저장
                face_image = Image.fromarray(frame[top-10:bottom+10, left-10:right+10])
                face_image.save(folder_path+'\\'+file_name[:-4]+' %d.jpg'%count)
                print('Saved frame%d.jpg' %count)
                count += 1

            except Exception as e:
                print("Exception Occurs.", e)
                pass

    video.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # 자동화

# %%
def main():

    directory = 'D:\\real'
    videolist = os.listdir( 'D:\\real')
    
    for video in videolist:
        try:
            #print(video)
            extract_frame(directory+'\\'+video)
        except Exception as e:
            print("Exception occurs.", e)

# %%
if __name__ == "__main__":
    main()
# Out:
# D:\real\M024_light_rightup_happy_camera_front.mp4
# A face is located at pixel location Top: 400, Left: 707, Bottom: 862, Right: 1170
# Saved frame0.jpg
# A face is located at pixel location Top: 418, Left: 849, Bottom: 973, Right: 1404
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_happy_camera_left.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_happy_camera_leftfront.mp4
# A face is located at pixel location Top: 390, Left: 1118, Bottom: 498, Right: 1226
# Saved frame0.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_happy_camera_right.mp4
# A face is located at pixel location Top: 400, Left: 399, Bottom: 862, Right: 861
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 451, Bottom: 862, Right: 913
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 348, Bottom: 862, Right: 810
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_happy_camera_rightfront.mp4
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame0.jpg
# A face is located at pixel location Top: 451, Left: 605, Bottom: 913, Right: 1067
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 502, Bottom: 862, Right: 964
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_happy_camera_up.mp4
# A face is located at pixel location Top: 461, Left: 675, Bottom: 846, Right: 1060
# Saved frame0.jpg
# A face is located at pixel location Top: 502, Left: 810, Bottom: 965, Right: 1272
# Saved frame1.jpg
# A face is located at pixel location Top: 451, Left: 656, Bottom: 913, Right: 1118
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_neutral_camera_down.mp4
# A face is located at pixel location Top: 333, Left: 632, Bottom: 718, Right: 1017
# Saved frame0.jpg
# A face is located at pixel location Top: 376, Left: 675, Bottom: 761, Right: 1060
# Saved frame1.jpg
# A face is located at pixel location Top: 333, Left: 632, Bottom: 718, Right: 1017
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_neutral_camera_front.mp4
# A face is located at pixel location Top: 348, Left: 759, Bottom: 811, Right: 1221
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 759, Bottom: 811, Right: 1221
# Saved frame1.jpg
# A face is located at pixel location Top: 348, Left: 759, Bottom: 811, Right: 1221
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_neutral_camera_left.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_neutral_camera_leftfront.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_neutral_camera_right.mp4
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 348, Left: 451, Bottom: 811, Right: 913
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 451, Bottom: 811, Right: 913
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_neutral_camera_rightfront.mp4
# A face is located at pixel location Top: 348, Left: 553, Bottom: 811, Right: 1016
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 605, Bottom: 811, Right: 1067
# Saved frame1.jpg
# A face is located at pixel location Top: 348, Left: 553, Bottom: 811, Right: 1016
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_neutral_camera_up.mp4
# A face is located at pixel location Top: 400, Left: 656, Bottom: 862, Right: 1118
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 656, Bottom: 862, Right: 1118
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 656, Bottom: 862, Right: 1118
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_sad_camera_down.mp4
# A face is located at pixel location Top: 376, Left: 632, Bottom: 761, Right: 1017
# Saved frame0.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 376, Left: 632, Bottom: 761, Right: 1017
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_sad_camera_front.mp4
# A face is located at pixel location Top: 400, Left: 707, Bottom: 862, Right: 1170
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 707, Bottom: 862, Right: 1170
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 707, Bottom: 862, Right: 1170
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_sad_camera_left.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_sad_camera_leftfront.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_sad_camera_right.mp4
# A face is located at pixel location Top: 400, Left: 399, Bottom: 862, Right: 861
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 399, Bottom: 862, Right: 861
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 399, Bottom: 862, Right: 861
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_sad_camera_rightfront.mp4
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 502, Bottom: 862, Right: 964
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 502, Bottom: 862, Right: 964
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_sad_camera_up.mp4
# A face is located at pixel location Top: 451, Left: 656, Bottom: 913, Right: 1118
# Saved frame0.jpg
# A face is located at pixel location Top: 461, Left: 675, Bottom: 846, Right: 1060
# Saved frame1.jpg
# A face is located at pixel location Top: 461, Left: 675, Bottom: 846, Right: 1060
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_surprise_camera_down.mp4
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 333, Left: 632, Bottom: 718, Right: 1017
# Saved frame0.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_surprise_camera_front.mp4
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 707, Bottom: 811, Right: 1170
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_surprise_camera_left.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_surprise_camera_leftfront.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_surprise_camera_right.mp4
# A face is located at pixel location Top: 400, Left: 399, Bottom: 862, Right: 861
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 399, Bottom: 811, Right: 861
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_surprise_camera_rightfront.mp4
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 553, Bottom: 811, Right: 1016
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_rightup_surprise_camera_up.mp4
# A face is located at pixel location Top: 451, Left: 656, Bottom: 913, Right: 1118
# Saved frame0.jpg
# A face is located at pixel location Top: 418, Left: 675, Bottom: 804, Right: 1060
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_angry_camera_down.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_angry_camera_front.mp4
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_angry_camera_left.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_angry_camera_leftfront.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_angry_camera_right.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_angry_camera_rightfront.mp4
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 399, Bottom: 862, Right: 861
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_angry_camera_up.mp4
# A face is located at pixel location Top: 461, Left: 718, Bottom: 846, Right: 1103
# Saved frame0.jpg
# A face is located at pixel location Top: 502, Left: 656, Bottom: 965, Right: 1118
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_contempt_camera_down.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_contempt_camera_front.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame0.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_contempt_camera_left.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_contempt_camera_leftfront.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 383, Left: 1171, Bottom: 512, Right: 1300
# Saved frame0.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_contempt_camera_right.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_contempt_camera_rightfront.mp4
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame0.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 400, Left: 451, Bottom: 862, Right: 913
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_contempt_camera_up.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 504, Left: 675, Bottom: 889, Right: 1060
# Saved frame0.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_disgust_camera_down.mp4
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 376, Left: 675, Bottom: 761, Right: 1060
# Saved frame0.jpg
# A face is located at pixel location Top: 376, Left: 675, Bottom: 761, Right: 1060
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_disgust_camera_front.mp4
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_disgust_camera_left.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_disgust_camera_leftfront.mp4
# A face is located at pixel location Top: 397, Left: 1199, Bottom: 526, Right: 1328
# Saved frame0.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_disgust_camera_right.mp4
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 400, Left: 399, Bottom: 862, Right: 861
# Saved frame0.jpg
# A face is located at pixel location Top: 357, Left: 295, Bottom: 911, Right: 849
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_disgust_camera_rightfront.mp4
# A face is located at pixel location Top: 357, Left: 418, Bottom: 911, Right: 972
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 502, Bottom: 862, Right: 964
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_disgust_camera_up.mp4
# A face is located at pixel location Top: 502, Left: 656, Bottom: 965, Right: 1118
# Saved frame0.jpg
# A face is located at pixel location Top: 504, Left: 718, Bottom: 889, Right: 1103
# Saved frame1.jpg
# A face is located at pixel location Top: 451, Left: 656, Bottom: 913, Right: 1118
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_fear_camera_down.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_fear_camera_front.mp4
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame0.jpg
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_fear_camera_left.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_fear_camera_leftfront.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_fear_camera_right.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_fear_camera_rightfront.mp4
# A face is located at pixel location Top: 357, Left: 479, Bottom: 911, Right: 1034
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 502, Bottom: 862, Right: 964
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_fear_camera_up.mp4
# A face is located at pixel location Top: 451, Left: 656, Bottom: 913, Right: 1118
# Saved frame0.jpg
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_happy_camera_down.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_happy_camera_front.mp4
# A face is located at pixel location Top: 400, Left: 707, Bottom: 862, Right: 1170
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 605, Bottom: 811, Right: 1067
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 861, Bottom: 862, Right: 1324
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_happy_camera_left.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_happy_camera_leftfront.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_happy_camera_right.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 400, Left: 451, Bottom: 862, Right: 913
# Saved frame0.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_happy_camera_rightfront.mp4
# A face is located at pixel location Top: 400, Left: 502, Bottom: 862, Right: 964
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 451, Bottom: 811, Right: 913
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 605, Bottom: 862, Right: 1067
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_happy_camera_up.mp4
# A face is located at pixel location Top: 461, Left: 675, Bottom: 846, Right: 1060
# Saved frame0.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 451, Left: 759, Bottom: 913, Right: 1221
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_neutral_camera_down.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_neutral_camera_front.mp4
# A face is located at pixel location Top: 348, Left: 759, Bottom: 811, Right: 1221
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 759, Bottom: 811, Right: 1221
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_neutral_camera_left.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_neutral_camera_leftfront.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 378, Left: 1142, Bottom: 486, Right: 1250
# Saved frame0.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_neutral_camera_right.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_neutral_camera_rightfront.mp4
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_neutral_camera_up.mp4
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 451, Left: 707, Bottom: 913, Right: 1170
# Saved frame0.jpg
# A face is located at pixel location Top: 461, Left: 718, Bottom: 846, Right: 1103
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_sad_camera_down.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_sad_camera_front.mp4
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 707, Bottom: 862, Right: 1170
# Saved frame1.jpg
# A face is located at pixel location Top: 348, Left: 656, Bottom: 811, Right: 1118
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_sad_camera_left.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_sad_camera_leftfront.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_sad_camera_right.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_sad_camera_rightfront.mp4
# A face is located at pixel location Top: 400, Left: 502, Bottom: 862, Right: 964
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 502, Bottom: 862, Right: 964
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 451, Bottom: 862, Right: 913
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_sad_camera_up.mp4
# A face is located at pixel location Top: 451, Left: 656, Bottom: 913, Right: 1118
# Saved frame0.jpg
# A face is located at pixel location Top: 504, Left: 675, Bottom: 889, Right: 1060
# Saved frame1.jpg
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_surprise_camera_down.mp4
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 376, Left: 675, Bottom: 761, Right: 1060
# Saved frame0.jpg
# A face is located at pixel location Top: 333, Left: 675, Bottom: 718, Right: 1060
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_surprise_camera_front.mp4
# A face is located at pixel location Top: 400, Left: 810, Bottom: 862, Right: 1272
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_surprise_camera_left.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_surprise_camera_leftfront.mp4
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_surprise_camera_right.mp4
# A face is located at pixel location Top: 400, Left: 451, Bottom: 862, Right: 913
# Saved frame0.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 295, Left: 356, Bottom: 850, Right: 911
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_surprise_camera_rightfront.mp4
# A face is located at pixel location Top: 400, Left: 605, Bottom: 862, Right: 1067
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 605, Bottom: 862, Right: 1067
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_right_surprise_camera_up.mp4
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 461, Left: 718, Bottom: 846, Right: 1103
# Saved frame0.jpg
# A face is located at pixel location Top: 461, Left: 718, Bottom: 846, Right: 1103
# Saved frame1.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_angry_camera_down.mp4
# A face is located at pixel location Top: 333, Left: 675, Bottom: 718, Right: 1060
# Saved frame0.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 333, Left: 632, Bottom: 718, Right: 1017
# Saved frame1.jpg
# A face is located at pixel location Top: 418, Left: 675, Bottom: 804, Right: 1060
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_angry_camera_front.mp4
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 759, Bottom: 811, Right: 1221
# Saved frame1.jpg
# A face is located at pixel location Top: 348, Left: 759, Bottom: 811, Right: 1221
# Saved frame2.jpg
# A face is located at pixel location Top: 400, Left: 810, Bottom: 862, Right: 1272
# Saved frame3.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_angry_camera_left.mp4
# A face is located at pixel location Top: 348, Left: 1016, Bottom: 811, Right: 1478
# Saved frame0.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 999, Left: 1158, Bottom: 1062, Right: 1220
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 1016, Bottom: 862, Right: 1478
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_angry_camera_leftfront.mp4
# A face is located at pixel location Top: 297, Left: 913, Bottom: 759, Right: 1375
# Saved frame0.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 297, Left: 913, Bottom: 759, Right: 1375
# Saved frame1.jpg
# A face is located at pixel location Top: 297, Left: 913, Bottom: 759, Right: 1375
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_angry_camera_right.mp4
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 348, Left: 451, Bottom: 811, Right: 913
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 399, Bottom: 811, Right: 861
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 451, Bottom: 862, Right: 913
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_angry_camera_rightfront.mp4
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 553, Bottom: 811, Right: 1016
# Saved frame1.jpg
# A face is located at pixel location Top: 348, Left: 553, Bottom: 811, Right: 1016
# Saved frame2.jpg
# A face is located at pixel location Top: 400, Left: 605, Bottom: 862, Right: 1067
# Saved frame3.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_angry_camera_up.mp4
# A face is located at pixel location Top: 461, Left: 718, Bottom: 846, Right: 1103
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 707, Bottom: 811, Right: 1170
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 656, Bottom: 862, Right: 1118
# Saved frame2.jpg
# A face is located at pixel location Top: 451, Left: 707, Bottom: 913, Right: 1170
# Saved frame3.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_contempt_camera_down.mp4
# A face is located at pixel location Top: 376, Left: 675, Bottom: 761, Right: 1060
# Saved frame0.jpg
# A face is located at pixel location Top: 376, Left: 675, Bottom: 761, Right: 1060
# Saved frame1.jpg
# A face is located at pixel location Top: 376, Left: 718, Bottom: 761, Right: 1103
# Saved frame2.jpg
# A face is located at pixel location Top: 376, Left: 718, Bottom: 761, Right: 1103
# Saved frame3.jpg
# A face is located at pixel location Top: 333, Left: 546, Bottom: 718, Right: 932
# Saved frame4.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_contempt_camera_front.mp4
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame1.jpg
# A face is located at pixel location Top: 348, Left: 810, Bottom: 811, Right: 1272
# Saved frame2.jpg
# A face is located at pixel location Top: 400, Left: 810, Bottom: 862, Right: 1272
# Saved frame3.jpg
# A face is located at pixel location Top: 348, Left: 656, Bottom: 811, Right: 1118
# Saved frame4.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_contempt_camera_left.mp4
# A face is located at pixel location Top: 400, Left: 1067, Bottom: 862, Right: 1529
# Saved frame0.jpg
# A face is located at pixel location Top: 348, Left: 964, Bottom: 811, Right: 1426
# Saved frame1.jpg
# A face is located at pixel location Top: 348, Left: 1067, Bottom: 811, Right: 1529
# Saved frame2.jpg
# A face is located at pixel location Top: 400, Left: 1118, Bottom: 862, Right: 1580
# Saved frame3.jpg
# A face is located at pixel location Top: 400, Left: 913, Bottom: 862, Right: 1375
# Saved frame4.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_contempt_camera_leftfront.mp4
# A face is located at pixel location Top: 376, Left: 974, Bottom: 761, Right: 1359
# Saved frame0.jpg
# A face is located at pixel location Top: 333, Left: 932, Bottom: 718, Right: 1317
# Saved frame1.jpg
# A face is located at pixel location Top: 333, Left: 974, Bottom: 718, Right: 1359
# Saved frame2.jpg
# A face is located at pixel location Top: 376, Left: 1017, Bottom: 761, Right: 1402
# Saved frame3.jpg
# A face is located at pixel location Top: 376, Left: 846, Bottom: 761, Right: 1231
# Saved frame4.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_contempt_camera_right.mp4
# A face is located at pixel location Top: 400, Left: 348, Bottom: 862, Right: 810
# Saved frame0.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 357, Left: 356, Bottom: 911, Right: 911
# Saved frame1.jpg
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_contempt_camera_rightfront.mp4
# A face is located at pixel location Top: 400, Left: 502, Bottom: 862, Right: 964
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame1.jpg
# A face is located at pixel location Top: 400, Left: 605, Bottom: 862, Right: 1067
# Saved frame2.jpg
# A face is located at pixel location Top: 400, Left: 605, Bottom: 862, Right: 1067
# Saved frame3.jpg
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_contempt_camera_up.mp4
# A face is located at pixel location Top: 504, Left: 718, Bottom: 889, Right: 1103
# Saved frame0.jpg
# A face is located at pixel location Top: 461, Left: 718, Bottom: 846, Right: 1103
# Saved frame1.jpg
# A face is located at pixel location Top: 461, Left: 760, Bottom: 846, Right: 1146
# Saved frame2.jpg
# A face is located at pixel location Top: 504, Left: 760, Bottom: 889, Right: 1146
# Saved frame3.jpg
# A face is located at pixel location Top: 418, Left: 589, Bottom: 804, Right: 974
# Saved frame4.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_disgust_camera_down.mp4
# A face is located at pixel location Top: 376, Left: 675, Bottom: 761, Right: 1060
# Saved frame0.jpg
# A face is located at pixel location Top: 418, Left: 675, Bottom: 804, Right: 1060
# Saved frame1.jpg
# A face is located at pixel location Top: 333, Left: 546, Bottom: 718, Right: 932
# Saved frame2.jpg
# A face is located at pixel location Top: 376, Left: 675, Bottom: 761, Right: 1060
# Saved frame3.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_disgust_camera_front.mp4
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame0.jpg
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame1.jpg
# A face is located at pixel location Top: 348, Left: 605, Bottom: 811, Right: 1067
# Saved frame2.jpg
# A face is located at pixel location Top: 400, Left: 759, Bottom: 862, Right: 1221
# Saved frame3.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_disgust_camera_left.mp4
# A face is located at pixel location Top: 400, Left: 1067, Bottom: 862, Right: 1529
# Saved frame0.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 348, Left: 913, Bottom: 811, Right: 1375
# Saved frame1.jpg
# A face is located at pixel location Top: 348, Left: 1067, Bottom: 811, Right: 1529
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_disgust_camera_leftfront.mp4
# A face is located at pixel location Top: 297, Left: 913, Bottom: 759, Right: 1375
# Saved frame0.jpg
# A face is located at pixel location Top: 418, Left: 932, Bottom: 804, Right: 1317
# Saved frame1.jpg
# A face is located at pixel location Top: 333, Left: 846, Bottom: 718, Right: 1231
# Saved frame2.jpg
# A face is located at pixel location Top: 297, Left: 964, Bottom: 759, Right: 1426
# Saved frame3.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_disgust_camera_right.mp4
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 451, Left: 451, Bottom: 913, Right: 913
# Saved frame0.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_disgust_camera_rightfront.mp4
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame0.jpg
# A face is located at pixel location Top: 451, Left: 553, Bottom: 913, Right: 1016
# Saved frame1.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 400, Left: 553, Bottom: 862, Right: 1016
# Saved frame2.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_disgust_camera_up.mp4
# A face is located at pixel location Top: 504, Left: 718, Bottom: 889, Right: 1103
# Saved frame0.jpg
# A face is located at pixel location Top: 461, Left: 718, Bottom: 846, Right: 1103
# Saved frame1.jpg
# A face is located at pixel location Top: 348, Left: 553, Bottom: 811, Right: 1016
# Saved frame2.jpg
# A face is located at pixel location Top: 451, Left: 707, Bottom: 913, Right: 1170
# Saved frame3.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M024_light_uniform_fear_camera_down.mp4
# A face is located at pixel location Top: 376, Left: 675, Bottom: 761, Right: 1060
# Saved frame0.jpg
# A face is located at pixel location Top: 376, Left: 632, Bottom: 761, Right: 1017
# Saved frame1.jpg
# ...
# A face is located at pixel location Top: 451, Left: 1067, Bottom: 913, Right: 1529
# Saved frame1.jpg
# A face is located at pixel location Top: 233, Left: 1096, Bottom: 788, Right: 1650
# Saved frame2.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 400, Left: 1067, Bottom: 862, Right: 1529
# Saved frame3.jpg
# A face is located at pixel location Top: 295, Left: 911, Bottom: 850, Right: 1466
# Saved frame4.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 194, Left: 964, Bottom: 657, Right: 1426
# Saved frame5.jpg
# A face is located at pixel location Top: 246, Left: 1067, Bottom: 708, Right: 1529
# Saved frame6.jpg
# A face is located at pixel location Top: 246, Left: 964, Bottom: 708, Right: 1426
# Saved frame7.jpg
# A face is located at pixel location Top: 194, Left: 964, Bottom: 657, Right: 1426
# Saved frame8.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 246, Left: 1067, Bottom: 708, Right: 1529
# Saved frame9.jpg
# A face is located at pixel location Top: 246, Left: 1016, Bottom: 708, Right: 1478
# Saved frame10.jpg
# A face is located at pixel location Top: 246, Left: 964, Bottom: 708, Right: 1426
# Saved frame11.jpg
# A face is located at pixel location Top: 246, Left: 1016, Bottom: 708, Right: 1478
# Saved frame12.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 246, Left: 861, Bottom: 708, Right: 1324
# Saved frame13.jpg
# A face is located at pixel location Top: 246, Left: 1016, Bottom: 708, Right: 1478
# Saved frame14.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 246, Left: 1016, Bottom: 708, Right: 1478
# Saved frame15.jpg
# A face is located at pixel location Top: 297, Left: 861, Bottom: 759, Right: 1324
# Saved frame16.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 297, Left: 1118, Bottom: 759, Right: 1580
# Saved frame17.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 246, Left: 1067, Bottom: 708, Right: 1529
# Saved frame18.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 246, Left: 1067, Bottom: 708, Right: 1529
# Saved frame19.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 297, Left: 1067, Bottom: 759, Right: 1529
# Saved frame20.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 297, Left: 964, Bottom: 759, Right: 1426
# Saved frame21.jpg
# A face is located at pixel location Top: 297, Left: 964, Bottom: 759, Right: 1426
# Saved frame22.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 297, Left: 913, Bottom: 759, Right: 1375
# Saved frame23.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 233, Left: 911, Bottom: 788, Right: 1466
# Saved frame24.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 348, Left: 1016, Bottom: 811, Right: 1478
# Saved frame25.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 297, Left: 1016, Bottom: 759, Right: 1478
# Saved frame26.jpg
# A face is located at pixel location Top: 297, Left: 964, Bottom: 759, Right: 1426
# Saved frame27.jpg
# A face is located at pixel location Top: 297, Left: 1272, Bottom: 759, Right: 1734
# Saved frame28.jpg
# A face is located at pixel location Top: 233, Left: 849, Bottom: 788, Right: 1404
# Saved frame29.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 297, Left: 913, Bottom: 759, Right: 1375
# Saved frame30.jpg
# A face is located at pixel location Top: 354, Left: 1241, Bottom: 1020, Right: 1907
# Saved frame31.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 297, Left: 1016, Bottom: 759, Right: 1478
# Saved frame32.jpg
# A face is located at pixel location Top: 297, Left: 861, Bottom: 759, Right: 1324
# Saved frame33.jpg
# A face is located at pixel location Top: 297, Left: 1118, Bottom: 759, Right: 1580
# Saved frame34.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 297, Left: 913, Bottom: 759, Right: 1375
# Saved frame35.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M025_BlendShape_camera_leftfront.mp4
# A face is located at pixel location Top: 194, Left: 1067, Bottom: 657, Right: 1529
# Saved frame0.jpg
# A face is located at pixel location Top: 194, Left: 1016, Bottom: 657, Right: 1478
# Saved frame1.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 194, Left: 1016, Bottom: 657, Right: 1478
# Saved frame2.jpg
# A face is located at pixel location Top: 194, Left: 1016, Bottom: 657, Right: 1478
# Saved frame3.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 400, Left: 861, Bottom: 862, Right: 1324
# Saved frame4.jpg
# A face is located at pixel location Top: 246, Left: 1016, Bottom: 708, Right: 1478
# Saved frame5.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 348, Left: 861, Bottom: 811, Right: 1324
# Saved frame6.jpg
# A face is located at pixel location Top: 297, Left: 810, Bottom: 759, Right: 1272
# Saved frame7.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 143, Left: 861, Bottom: 605, Right: 1324
# Saved frame8.jpg
# A face is located at pixel location Top: 194, Left: 913, Bottom: 657, Right: 1375
# Saved frame9.jpg
# A face is located at pixel location Top: 143, Left: 810, Bottom: 605, Right: 1272
# Saved frame10.jpg
# A face is located at pixel location Top: 143, Left: 861, Bottom: 605, Right: 1324
# Saved frame11.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 194, Left: 964, Bottom: 657, Right: 1426
# Saved frame12.jpg
# A face is located at pixel location Top: 194, Left: 861, Bottom: 657, Right: 1324
# Saved frame13.jpg
# A face is located at pixel location Top: 194, Left: 861, Bottom: 657, Right: 1324
# Saved frame14.jpg
# A face is located at pixel location Top: 194, Left: 861, Bottom: 657, Right: 1324
# Saved frame15.jpg
# A face is located at pixel location Top: 194, Left: 1016, Bottom: 657, Right: 1478
# Saved frame16.jpg
# A face is located at pixel location Top: 204, Left: 1017, Bottom: 590, Right: 1402
# Saved frame17.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 194, Left: 861, Bottom: 657, Right: 1324
# Saved frame18.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 194, Left: 1016, Bottom: 657, Right: 1478
# Saved frame19.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 247, Left: 932, Bottom: 632, Right: 1317
# Saved frame20.jpg
# A face is located at pixel location Top: 194, Left: 759, Bottom: 657, Right: 1221
# Saved frame21.jpg
# A face is located at pixel location Top: 194, Left: 1016, Bottom: 657, Right: 1478
# Saved frame22.jpg
# A face is located at pixel location Top: 246, Left: 964, Bottom: 708, Right: 1426
# Saved frame23.jpg
# A face is located at pixel location Top: 247, Left: 1017, Bottom: 632, Right: 1402
# Saved frame24.jpg
# A face is located at pixel location Top: 194, Left: 964, Bottom: 657, Right: 1426
# Saved frame25.jpg
# A face is located at pixel location Top: 246, Left: 1170, Bottom: 708, Right: 1632
# Saved frame26.jpg
# A face is located at pixel location Top: 247, Left: 974, Bottom: 632, Right: 1359
# Saved frame27.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 246, Left: 913, Bottom: 708, Right: 1375
# Saved frame28.jpg
# A face is located at pixel location Top: 246, Left: 964, Bottom: 708, Right: 1426
# Saved frame29.jpg
# A face is located at pixel location Top: 246, Left: 810, Bottom: 708, Right: 1272
# Saved frame30.jpg
# A face is located at pixel location Top: 172, Left: 788, Bottom: 726, Right: 1342
# Saved frame31.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 246, Left: 810, Bottom: 708, Right: 1272
# Saved frame32.jpg
# A face is located at pixel location Top: 194, Left: 964, Bottom: 657, Right: 1426
# Saved frame33.jpg
# A face is located at pixel location Top: 246, Left: 1170, Bottom: 708, Right: 1632
# Saved frame34.jpg
# A face is located at pixel location Top: 194, Left: 810, Bottom: 657, Right: 1272
# Saved frame35.jpg
# A face is located at pixel location Top: 246, Left: 1016, Bottom: 708, Right: 1478
# Saved frame36.jpg
# A face is located at pixel location Top: 246, Left: 810, Bottom: 708, Right: 1272
# Saved frame37.jpg
# A face is located at pixel location Top: 246, Left: 1067, Bottom: 708, Right: 1529
# Saved frame38.jpg
# A face is located at pixel location Top: 246, Left: 1221, Bottom: 708, Right: 1683
# Saved frame39.jpg
# A face is located at pixel location Top: 246, Left: 861, Bottom: 708, Right: 1324
# Saved frame40.jpg
# A face is located at pixel location Top: 246, Left: 810, Bottom: 708, Right: 1272
# Saved frame41.jpg
# A face is located at pixel location Top: 246, Left: 1118, Bottom: 708, Right: 1580
# Saved frame42.jpg
# A face is located at pixel location Top: 246, Left: 759, Bottom: 708, Right: 1221
# Saved frame43.jpg
# A face is located at pixel location Top: 194, Left: 964, Bottom: 657, Right: 1426
# Saved frame44.jpg
# A face is located at pixel location Top: 246, Left: 810, Bottom: 708, Right: 1272
# Saved frame45.jpg
# A face is located at pixel location Top: 400, Left: 1118, Bottom: 862, Right: 1580
# Saved frame46.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 246, Left: 861, Bottom: 708, Right: 1324
# Saved frame47.jpg
# A face is located at pixel location Top: 246, Left: 759, Bottom: 708, Right: 1221
# Saved frame48.jpg
# A face is located at pixel location Top: 297, Left: 964, Bottom: 759, Right: 1426
# Saved frame49.jpg
# A face is located at pixel location Top: 246, Left: 1067, Bottom: 708, Right: 1529
# Saved frame50.jpg
# A face is located at pixel location Top: 246, Left: 964, Bottom: 708, Right: 1426
# Saved frame51.jpg
# A face is located at pixel location Top: 246, Left: 1016, Bottom: 708, Right: 1478
# Saved frame52.jpg
# A face is located at pixel location Top: 246, Left: 810, Bottom: 708, Right: 1272
# Saved frame53.jpg
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M025_BlendShape_camera_right.mp4
# A face is located at pixel location Top: 172, Left: 295, Bottom: 726, Right: 849
# Saved frame0.jpg
# A face is located at pixel location Top: 233, Left: 295, Bottom: 788, Right: 849
# Saved frame1.jpg
# A face is located at pixel location Top: 297, Left: 451, Bottom: 759, Right: 913
# Saved frame2.jpg
# A face is located at pixel location Top: 233, Left: 233, Bottom: 788, Right: 788
# Saved frame3.jpg
# A face is located at pixel location Top: 172, Left: 233, Bottom: 726, Right: 788
# Saved frame4.jpg
# A face is located at pixel location Top: 418, Left: 418, Bottom: 973, Right: 972
# Saved frame5.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 233, Left: 233, Bottom: 788, Right: 788
# Saved frame6.jpg
# A face is located at pixel location Top: 357, Left: 479, Bottom: 911, Right: 1034
# Saved frame7.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 357, Left: 418, Bottom: 911, Right: 972
# Saved frame8.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 246, Left: 553, Bottom: 708, Right: 1016
# Saved frame9.jpg
# A face is located at pixel location Top: 233, Left: 295, Bottom: 788, Right: 849
# Saved frame10.jpg
# A face is located at pixel location Top: 246, Left: 553, Bottom: 708, Right: 1016
# Saved frame11.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 246, Left: 502, Bottom: 708, Right: 964
# Saved frame12.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 233, Left: 479, Bottom: 788, Right: 1034
# Saved frame13.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 233, Left: 603, Bottom: 788, Right: 1157
# Saved frame14.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 295, Left: 418, Bottom: 850, Right: 972
# Saved frame15.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 233, Left: 295, Bottom: 788, Right: 849
# Saved frame16.jpg
# A face is located at pixel location Top: 297, Left: 553, Bottom: 759, Right: 1016
# Saved frame17.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 297, Left: 502, Bottom: 759, Right: 964
# Saved frame18.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 357, Left: 356, Bottom: 911, Right: 911
# Saved frame19.jpg
# A face is located at pixel location Top: 295, Left: 479, Bottom: 850, Right: 1034
# Saved frame20.jpg
# Exception Occurs. list index out of range
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 233, Left: 233, Bottom: 788, Right: 788
# Saved frame21.jpg
# A face is located at pixel location Top: 233, Left: 356, Bottom: 788, Right: 911
# Saved frame22.jpg
# Exception Occurs. list index out of range
# A face is located at pixel location Top: 233, Left: 233, Bottom: 788, Right: 788
# Saved frame23.jpg
# Exception Occurs. list index out of range
# Exception occurs. OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
#
# D:\real\M025_BlendShape_camera_rightfront.mp4
# A face is located at pixel location Top: 246, Left: 553, Bottom: 708, Right: 1016
# Saved frame0.jpg
# A face is located at pixel location Top: 233, Left: 479, Bottom: 788, Right: 1034
# Saved frame1.jpg
# A face is located at pixel location Top: 297, Left: 656, Bottom: 759, Right: 1118
# Saved frame2.jpg
# A face is located at pixel location Top: 233, Left: 418, Bottom: 788, Right: 972
# Saved frame3.jpg
# A face is located at pixel location Top: 246, Left: 502, Bottom: 708, Right: 964
# Saved frame4.jpg
# A face is located at pixel location Top: 480, Left: 664, Bottom: 1035, Right: 1219
# Saved frame5.jpg

# %% [markdown]
# # 몇 장만 뽑아내는 걸로 수정하기

# %% [markdown]
# # 여기부터 안해도 됨!

# %%
#얼굴 탐지
def faceDetect(path, videoname, idnum):
    eye_detect = False
    face_cascade = cv2.CascadeClassifier('haarcascade_frontface.xml')
    eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
    info = ''
    count = 0
    
    try:
        video = cv2.VideoCapture(path)
    except:
        print('video loading failed.')
        return
    
    while True:
        ret, frame = video.read()
        if not ret:
            break
        if eye_detect:
            info = "Eye detection on"
        else:
            info = "Eye detection off"
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3,5)
        #top, right, bottom, left = faces
        print(faces)
        #for (x,y,w,h) in faces:
        print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

        #face_location 찾아서 파일로 저장
        face_image = Image.fromarray(frame[top:bottom, left:right])
        #Image.fromarray(face_image).show()
        face_image.save(videoname+'/'+idnum+'frame %d.jpg' %count)
        print('Saved frame%d.jpg' %count)
        count += 1

# %%
#cascade 분류기를 사용한 얼굴인식

import cv2
import numpy as np
import face_recognition
import re
from matplotlib import pyplot as plt

dirname = 'deepfake-data_subset1/original_videos/'
videoname = '643049'
classnum = '_D_001'
video_path = dirname + videoname+'/'
frame_save_path = videoname+'/'+classnum+'_frame'
path = video_path+videoname+classnum+'.mp4'
#'C:\Users\user\Documents\cyber17\Face_Detection\'
video = cv2.VideoCapture(path)

videoframe = video.get(cv2.CAP_PROP_POS_FRAMES)
videocount = video.get(cv2.CAP_PROP_FRAME_COUNT)

createfolder(frame_save_path)

while video.isOpened():
    #ret 은 프레임이 존재하지 않을때 T/F 반환
    #frame 은 프레임 반환
    if(videoframe == videocount):
        video.open(path)
    
    faceDetect(path, videoname,classnum)


video.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 여기는 얼굴 세부사항(눈, 코, 입, 귀 등) 표시용.
#
# ## 필요없다고 함~

# %%
import face_alignment
from skimage import io
import os

videoname = 'sample1'
framepath = videoname+'_frame '

fa = face_alignment.FaceAlignment(face_alignment.LandmarksType._3D, flip_input=False)

count=0
for i in range(5): #len(os.walk(path).__next__()[2]
    print("start : ", i)
    input = io.imread(framepath+str(i)+'.jpg')
    preds = fa.get_landmarks(input)
    preds = Image.fromarray(preds)
    display(preds)
    #preds.save(videoname+'_frame_face/feature %d.jpg' %count)
    count += 1
