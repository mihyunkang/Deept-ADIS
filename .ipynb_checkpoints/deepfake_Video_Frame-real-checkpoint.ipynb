# %%
import os
def createfolder(folder):
    try:
        if not os.path.exists(folder):
            os.makedirs(folder)
    except OSError:
        print('Error: creating directory' + folder)

# %%
import PIL
from PIL import Image

def load_image_file(file, mode='RGB'):
    im = PIL.Image.open(file)
    if mode:
        im = im.convert(mode)
    return np.array(im)

# %%
import cv2
import numpy as np
import face_recognition
import re
import os


# 한 디렉토리 안의 모든 비디오 파일들에 대해.
def directory_video(directory, videoname):
    video_path = directory + videoname+'/'
    #frame_save = videoname+'_frame'
    #print(frame_save)
    
    video_files = os.listdir(video_path)
    for file in video_files:
        extract_frame(video_path+file)

# %%
# 비디오에 대해 프레임 추출
#frame_save_path = videoname+'_frame'

def extract_frame(filename):
    #path 
    print(filename)
    
    folder_path = filename.split('/')[2]
    file_name = filename.split('/')[3]
    video = cv2.VideoCapture(filename)
    count = 0
    
    #create save folders
    createfolder(folder_path)
    
    videoframe = video.get(cv2.CAP_PROP_POS_FRAMES)
    videocount = video.get(cv2.CAP_PROP_FRAME_COUNT)

    while video.isOpened():
        #ret 은 프레임이 존재하지 않을때 T/F 반환
        #frame 은 프레임 반환
        if(videoframe == videocount):
            video.open(filename)
            
        ret, frame = video.read()

        if ret == False:
            print("Frame doesn't Exist")
            break

        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    

        try:

            #face_location 은 얼굴 위치(행렬에서)
            face_location = face_recognition.face_locations(frame) #cnn 모델 사용 X. 원할시, model='cnn' 입력(GPU 없는 기기에서는 실행되지 않음)
            top, right, bottom, left = face_location[0]
            print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

            #face_location 찾아서 파일로 저장
            face_image = Image.fromarray(frame[top-10:bottom+10, left-10:right+10])
            face_image.save(folder_path+'/'+file_name[:-4]+' %d.jpg'%count)
            print('Saved frame%d.jpg' %count)
            count += 1

        except Exception as e:
            print("Exception Occurs.", e)
            pass

    video.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # 자동화

# %%
def main():

    directory = 'deepfake-data_subset1/original_videos/'
    videolist = os.listdir( 'deepfake-data_subset1/original_videos')
    
    for video in videolist:
        if video != '.DS_Store':
            directory_video(directory, video)

# %%
if __name__ == "__main__":
    main()
# Out:
# deepfake-data_subset1/original_videos/804259/804259_B_001.mp4
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame0.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame1.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame2.jpg
# A face is located at pixel location Top: 284, Left: 923, Bottom: 469, Right: 1109
# Saved frame3.jpg
# A face is located at pixel location Top: 284, Left: 923, Bottom: 469, Right: 1109
# Saved frame4.jpg
# A face is located at pixel location Top: 284, Left: 923, Bottom: 469, Right: 1109
# Saved frame5.jpg
# A face is located at pixel location Top: 284, Left: 923, Bottom: 469, Right: 1109
# Saved frame6.jpg
# A face is located at pixel location Top: 284, Left: 923, Bottom: 469, Right: 1109
# Saved frame7.jpg
# A face is located at pixel location Top: 305, Left: 941, Bottom: 460, Right: 1096
# Saved frame8.jpg
# A face is located at pixel location Top: 305, Left: 941, Bottom: 460, Right: 1096
# Saved frame9.jpg
# A face is located at pixel location Top: 305, Left: 941, Bottom: 460, Right: 1096
# Saved frame10.jpg
# A face is located at pixel location Top: 305, Left: 941, Bottom: 460, Right: 1096
# Saved frame11.jpg
# A face is located at pixel location Top: 305, Left: 941, Bottom: 460, Right: 1096
# Saved frame12.jpg
# A face is located at pixel location Top: 305, Left: 941, Bottom: 460, Right: 1096
# Saved frame13.jpg
# A face is located at pixel location Top: 305, Left: 941, Bottom: 460, Right: 1096
# Saved frame14.jpg
# A face is located at pixel location Top: 305, Left: 941, Bottom: 460, Right: 1096
# Saved frame15.jpg
# A face is located at pixel location Top: 305, Left: 958, Bottom: 460, Right: 1113
# Saved fr
# A face is located at pixel location Top: 263, Left: 944, Bottom: 449, Right: 1129
# Saved frame0.jpg
# A face is located at pixel location Top: 263, Left: 944, Bottom: 449, Right: 1129
# Saved frame1.jpg
# A face is located at pixel location Top: 263, Left: 944, Bottom: 449, Right: 1129
# Saved frame2.jpg
# A face is located at pixel location Top: 263, Left: 944, Bottom: 449, Right: 1129
# Saved frame3.jpg
# A face is located at pixel location Top: 263, Left: 944, Bottom: 449, Right: 1129
# Saved frame4.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame5.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame6.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame7.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame8.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame9.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame10.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame11.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame12.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame13.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame14.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame15.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame16.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame17.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame18.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame19.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame20.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame21.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame22.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame23.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame24.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame25.jpg
# A face is located at pixel location Top: 263, Left: 923, Bottom: 449, Right: 1109
# Saved frame26.jpg
# ...
# Saved frame118.jpg
# A face is located at pixel location Top: 201, Left: 820, Bottom: 387, Right: 1005
# Saved frame119.jpg
# A face is located at pixel location Top: 201, Left: 820, Bottom: 387, Right: 1005
# Saved frame120.jpg
# A face is located at pixel location Top: 201, Left: 820, Bottom: 387, Right: 1005
# Saved frame121.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame122.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame123.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame124.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame125.jpg
# A face is located at pixel location Top: 201, Left: 820, Bottom: 387, Right: 1005
# Saved frame126.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame127.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame128.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame129.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame130.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame131.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame132.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame133.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame134.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame135.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame136.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame137.jpg
# A face is located at pixel location Top: 217, Left: 811, Bottom: 440, Right: 1034
# Saved frame138.jpg
# A face is located at pixel location Top: 217, Left: 811, Bottom: 440, Right: 1034
# Saved frame139.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame140.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame141.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame142.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame143.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame144.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame145.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame146.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame147.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame148.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame149.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame150.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame151.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame152.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame153.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame154.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame155.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame156.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame157.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame158.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame159.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame160.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame161.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame162.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame163.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame164.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame165.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame166.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame167.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame168.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame169.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame170.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame171.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame172.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame173.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame174.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame175.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame176.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame177.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame178.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame179.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame180.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame181.jpg
# A face is located at pixel location Top: 222, Left: 820, Bottom: 407, Right: 1005
# Saved frame182.jpg
# A face is located at pixel location Top: 201, Left: 820, Bottom: 387, Right: 1005
# Saved frame183.jpg
# A face is located at pixel location Top: 201, Left: 820, Bottom: 387, Right: 1005
# Saved frame184.jpg
# A face is located at pixel location Top: 201, Left: 820, Bottom: 387, Right: 1005
# Saved frame185.jpg
# A face is located at pixel location Top: 201, Left: 820, Bottom: 387, Right: 1005
# Saved frame186.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame187.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame188.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame189.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame190.jpg
# A face is located at pixel location Top: 222, Left: 840, Bottom: 407, Right: 1026
# Saved frame191.jpg
# A face is located at pixel location Top: 222, Left: 861, Bottom: 407, Right: 1047
# Saved frame192.jpg
# A face is located at pixel location Top: 222, Left: 861, Bottom: 407, Right: 1047
# Saved frame193.jpg
# A face is located at pixel location Top: 222, Left: 882, Bottom: 407, Right: 1067
# Saved frame194.jpg
# A face is located at pixel location Top: 222, Left: 882, Bottom: 407, Right: 1067
# Saved frame195.jpg
# A face is located at pixel location Top: 222, Left: 882, Bottom: 407, Right: 1067
# Saved frame196.jpg
# A face is located at pixel location Top: 236, Left: 906, Bottom: 391, Right: 1061
# Saved frame197.jpg
# A face is located at pixel location Top: 242, Left: 902, Bottom: 428, Right: 1088
# Saved frame198.jpg
# A face is located at pixel location Top: 242, Left: 902, Bottom: 428, Right: 1088
# Saved frame199.jpg
# A face is located at pixel location Top: 242, Left: 902, Bottom: 428, Right: 1088
# Saved frame200.jpg
# A face is located at pixel location Top: 242, Left: 902, Bottom: 428, Right: 1088
# Saved frame201.jpg
# A face is located at pixel location Top: 242, Left: 902, Bottom: 428, Right: 1088
# Saved frame202.jpg
# A face is located at pixel location Top: 242, Left: 902, Bottom: 428, Right: 1088
# Saved frame203.jpg
# A face is located at pixel location Top: 242, Left: 902, Bottom: 428, Right: 1088
# Saved frame204.jpg
# A face is located at pixel location Top: 242, Left: 902, Bottom: 428, Right: 1088
# Saved frame205.jpg
# A face is located at pixel location Top: 242, Left: 902, Bottom: 428, Right: 1088
# Saved frame206.jpg
# A face is located at pixel location Top: 242, Left: 902, Bottom: 428, Right: 1088
# Saved frame207.jpg
# A face is located at pixel location Top: 242, Left: 902, Bottom: 428, Right: 1088
# Saved frame208.jpg
# A face is located at pixel location Top: 222, Left: 882, Bottom: 407, Right: 1067
# Saved frame209.jpg
# A face is located at pixel location Top: 222, Left: 882, Bottom: 407, Right: 1067
# Saved frame210.jpg
# A face is located at pixel location Top: 222, Left: 882, Bottom: 407, Right: 1067
# Saved frame211.jpg
# A face is located at pixel location Top: 222, Left: 882, Bottom: 407, Right: 1067
# Saved frame212.jpg
# A face is located at pixel location Top: 201, Left: 861, Bottom: 387, Right: 1047
# Saved frame213.jpg
# A face is located at pixel location Top: 201, Left: 861, Bottom: 387, Right: 1047
# Saved frame214.jpg
# A face is located at pixel location Top: 201, Left: 861, Bottom: 387, Right: 1047
# Saved frame215.jpg
# A face is located at pixel location Top: 192, Left: 835, Bottom: 415, Right: 1058
# Saved frame216.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame217.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame218.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame219.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame220.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame221.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame222.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame223.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame224.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame225.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame226.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame227.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame228.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame229.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame230.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame231.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame232.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame233.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame234.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame235.jpg
# A face is located at pixel location Top: 201, Left: 840, Bottom: 387, Right: 1026
# Saved frame236.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame237.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame238.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame239.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame240.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame241.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame242.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame243.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame244.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame245.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame246.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame247.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame248.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame249.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame250.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame251.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame252.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame253.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame254.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame255.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame256.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame257.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame258.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame259.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame260.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame261.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame262.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame263.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame264.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame265.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame266.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame267.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame268.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame269.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame270.jpg
# A face is located at pixel location Top: 201, Left: 820, Bottom: 387, Right: 1005
# Saved frame271.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame272.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame273.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame274.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame275.jpg
# A face is located at pixel location Top: 192, Left: 811, Bottom: 415, Right: 1034
# Saved frame276.jpg

# %% [markdown]
# # 몇 장만 뽑아내는 걸로 수정하기

# %% [markdown]
# # 여기부터 안해도 됨!

# %%
#얼굴 탐지
def faceDetect(path, videoname, idnum):
    eye_detect = False
    face_cascade = cv2.CascadeClassifier('haarcascade_frontface.xml')
    eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')
    info = ''
    count = 0
    
    try:
        video = cv2.VideoCapture(path)
    except:
        print('video loading failed.')
        return
    
    while True:
        ret, frame = video.read()
        if not ret:
            break
        if eye_detect:
            info = "Eye detection on"
        else:
            info = "Eye detection off"
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3,5)
        #top, right, bottom, left = faces
        print(faces)
        #for (x,y,w,h) in faces:
        print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

        #face_location 찾아서 파일로 저장
        face_image = Image.fromarray(frame[top:bottom, left:right])
        #Image.fromarray(face_image).show()
        face_image.save(videoname+'/'+idnum+'frame %d.jpg' %count)
        print('Saved frame%d.jpg' %count)
        count += 1

# %%
#cascade 분류기를 사용한 얼굴인식

import cv2
import numpy as np
import face_recognition
import re
from matplotlib import pyplot as plt

dirname = 'deepfake-data_subset1/original_videos/'
videoname = '643049'
classnum = '_D_001'
video_path = dirname + videoname+'/'
frame_save_path = videoname+'/'+classnum+'_frame'
path = video_path+videoname+classnum+'.mp4'
#'C:\Users\user\Documents\cyber17\Face_Detection\'
video = cv2.VideoCapture(path)

videoframe = video.get(cv2.CAP_PROP_POS_FRAMES)
videocount = video.get(cv2.CAP_PROP_FRAME_COUNT)

createfolder(frame_save_path)

while video.isOpened():
    #ret 은 프레임이 존재하지 않을때 T/F 반환
    #frame 은 프레임 반환
    if(videoframe == videocount):
        video.open(path)
    
    faceDetect(path, videoname,classnum)


video.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 여기는 얼굴 세부사항(눈, 코, 입, 귀 등) 표시용.
#
# ## 필요없다고 함~

# %%
import face_alignment
from skimage import io
import os

videoname = 'sample1'
framepath = videoname+'_frame '

fa = face_alignment.FaceAlignment(face_alignment.LandmarksType._3D, flip_input=False)

count=0
for i in range(5): #len(os.walk(path).__next__()[2]
    print("start : ", i)
    input = io.imread(framepath+str(i)+'.jpg')
    preds = fa.get_landmarks(input)
    preds = Image.fromarray(preds)
    display(preds)
    #preds.save(videoname+'_frame_face/feature %d.jpg' %count)
    count += 1
