# %%
import os
def createfolder(folder):
    try:
        if not os.path.exists(folder):
            os.makedirs(folder)
    except OSError:
        print('Error: creating directory' + folder)

# %%
import PIL
from PIL import Image
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

def load_image_file(file, mode='RGB'):
    im = PIL.Image.open(file)
    if mode:
        im = im.convert(mode)
    if torch.cuda.device_count() > 1:
        im = nn.DataParallel(np.array(im))
    return im.to(device)
# Out:
# cuda

# %%
import cv2
import numpy as np
import face_recognition
import re
import os


# 같은 메소드로 만든 모든 비디오 파일들에 대해.
def directory_video(method, videoname):
    video_path = method + '/' + videoname
    print(video_path)
    #print(os.listdir(video_path))
    video_files = os.listdir(video_path)
    for file in video_files:
        extract_frame(video_path+"/"+file)

# %%
# 비디오에 대해 프레임 추출
#frame_save_path = videoname+'_frame'

def extract_frame(filename):
    #path 
    print(filename)
    
    folder_path = filename.split('/')[1]
    file_name = filename.split('/')[2].split('_')
    video = cv2.VideoCapture(filename)
    count = 0
    num = 0
    #create save folder
    folder = folder_path + '_face' #fake_method_A_face 폴더
    createfolder(folder)
    
    videoframe = video.get(cv2.CAP_PROP_POS_FRAMES)
    videocount = video.get(cv2.CAP_PROP_FRAME_COUNT)

    while video.isOpened():
        #ret 은 프레임이 존재하지 않을때 T/F 반환
        #frame 은 프레임 반환
        num += 1
        if num % 50000 == 0:
            print(num)
            if(videoframe == videocount):
                video.open(filename)
            
            ret, frame = video.read()

            if ret == False:
                print("Frame doesn't Exist")
                break

            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)    

            try:

                #face_location 은 얼굴 위치(행렬에서)
                face_location = face_recognition.face_locations(frame) #cnn 모델 사용 X. 원할시, model='cnn' 입력(GPU 없는 기기에서는 실행되지 않음)
                top, right, bottom, left = face_location[0]
                #print(frame.shape) (1920, 1080, 3)
                print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

                #face_location 찾아서 파일로 저장
                if 0 <= top-10 and bottom < len(frame) and 0 <= left and right+10 < len(frame[0]):
                    face_image = Image.fromarray(frame[top-10:bottom+10, left-10:right+10])
                    face_image.save(folder+'/'+file_name[0]+'_'+file_name[1]+'_'+filename[-9:-8]+'_'+filename[-7:-4]+'_%d.jpg'%count)
                    print('Saved frame%d.jpg' %count)
                    count += 1
                else:
                    continue

            except Exception as e:
                print("Exception Occurs.", e)
                pass

    video.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ### 자동화

# %%
def main():

    directory = './data'
    typelist = os.listdir( './data') #methodA, methodB, real
    
#    for type in typelist:
    directory_video(directory, 'fake_methodB') #type 폴더 내로 진입

# %%
if __name__ == "__main__":
    main()
# Out:
# ./data/fake_methodB
# ./data/fake_methodB/1853436_1929178_D_001.mp4
# A face is located at pixel location Top: 180, Left: 820, Bottom: 366, Right: 1005
# Saved frame0.jpg
# A face is located at pixel location Top: 180, Left: 820, Bottom: 366, Right: 1005
# Saved frame1.jpg
# A face is located at pixel location Top: 180, Left: 820, Bottom: 366, Right: 1005
# Saved frame2.jpg
# A face is located at pixel location Top: 180, Left: 820, Bottom: 366, Right: 1005
# Saved frame3.jpg
# A face is located at pixel location Top: 180, Left: 820, Bottom: 366, Right: 1005
# Saved frame4.jpg
# A face is located at pixel location Top: 180, Left: 820, Bottom: 366, Right: 1005
# Saved frame5.jpg
# A face is located at pixel location Top: 180, Left: 820, Bottom: 366, Right: 1005
# Saved frame6.jpg
# A face is located at pixel location Top: 180, Left: 799, Bottom: 366, Right: 985
# Saved frame7.jpg
# A face is located at pixel location Top: 180, Left: 799, Bottom: 366, Right: 985
# Saved frame8.jpg
# A face is located at pixel location Top: 180, Left: 799, Bottom: 366, Right: 985
# Saved frame9.jpg
# A face is located at pixel location Top: 180, Left: 799, Bottom: 366, Right: 985
# Saved frame10.jpg
# A face is located at pixel location Top: 180, Left: 799, Bottom: 366, Right: 985
# Saved frame11.jpg
# A face is located at pixel location Top: 180, Left: 799, Bottom: 366, Right: 985
# Saved frame12.jpg
# A face is located at pixel location Top: 180, Left: 799, Bottom: 366, Right: 985
# Saved frame13.jpg
# A face is located at pixel location Top: 180, Left: 799, Bottom: 366, Right: 985
# Saved frame14.jpg
# A face is located at pixel location Top: 180, Left: 778, Bottom: 366, Right: 964
# Saved frame15.jpg
# A face is located at pixel location Top: 180, Left: 778, Bottom: 366, Right: 964
# Saved frame16.jpg
# A face is located at pixel location Top: 202, Left: 786, Bottom: 356, Right: 941
# Saved frame17.jpg
# A face is located at pixel location Top: 180, Left: 758, Bottom: 366, Right: 944
# Saved frame18.jpg
# A face is located at pixel location Top: 180, Left: 758, Bottom: 366, Right: 944
# Saved frame19.jpg
# A face is located at pixel location Top: 202, Left: 769, Bottom: 356, Right: 924
# Saved frame20.jpg
# A face is located at pixel location Top: 202, Left: 752, Bottom: 356, Right: 906
# Saved frame21.jpg
# A face is located at pixel location Top: 180, Left: 737, Bottom: 366, Right: 923
# Saved frame22.jpg
# A face is located at pixel location Top: 202, Left: 752, Bottom: 356, Right: 906
# Saved frame23.jpg
# A face is located at pixel location Top: 180, Left: 737, Bottom: 366, Right: 923
# Saved frame24.jpg
# A face is located at pixel location Top: 202, Left: 752, Bottom: 356, Right: 906
# Saved frame25.jpg
# A face is located at pixel location Top: 202, Left: 752, Bottom: 356, Right: 906
# Saved frame26.jpg
# A face is located at pixel location Top: 202, Left: 752, Bottom: 356, Right: 906
# Saved frame27.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame28.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame29.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame30.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame31.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame32.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame33.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame34.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame35.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame36.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame37.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame38.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame39.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame40.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame41.jpg
# A face is located at pixel location Top: 202, Left: 734, Bottom: 356, Right: 889
# Saved frame42.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-972361fa1b80> in <module>
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# <ipython-input-82-b6fcd14b9745> in main()
#       5
#       6 #    for type in typelist:
# ----> 7     directory_video(directory, 'fake_methodB') #type 폴더 내로 진입
#
# <ipython-input-64-5ae15ab303f1> in directory_video(method, videoname)
#      13     video_files = os.listdir(video_path)
#      14     for file in video_files:
# ---> 15         extract_frame(video_path+"/"+file)
#
# <ipython-input-81-12ec69282d08> in extract_frame(filename)
#      38
#      39                 #face_location 은 얼굴 위치(행렬에서)
# ---> 40                 face_location = face_recognition.face_locations(frame) #cnn 모델 사용 X. 원할시, model='cnn' 입력(GPU 없는 기기에서는 실행되지 않음)
#      41                 top, right, bottom, left = face_location[0]
#      42                 #print(frame.shape) (1920, 1080, 3)
#
# ~/anaconda3/envs/pytorch_default/lib/python3.6/site-packages/face_recognition/api.py in face_locations(img, number_of_times_to_upsample, model)
#     119         return [_trim_css_to_bounds(_rect_to_css(face.rect), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, "cnn")]
#     120     else:
# --> 121         return [_trim_css_to_bounds(_rect_to_css(face), img.shape) for face in _raw_face_locations(img, number_of_times_to_upsample, model)]
#     122
#     123
#
# ~/anaconda3/envs/pytorch_default/lib/python3.6/site-packages/face_recognition/api.py in _raw_face_locations(img, number_of_times_to_upsample, model)
#     103         return cnn_face_detector(img, number_of_times_to_upsample)
#     104     else:
# --> 105         return face_detector(img, number_of_times_to_upsample)
#     106
#     107
#
# KeyboardInterrupt:
